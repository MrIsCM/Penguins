# %% [markdown]
# # -- Penguins --
#
# Some analysis/visualisations about penguins and their properties

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pengs_iterDF = pd.read_csv('penguins_lter.csv').dropna()
pengs_sizeDF = pd.read_csv('penguins_size.csv').dropna()

# %%
pengs_sizeDF['species'].value_counts()
# Out:
# Adelie       146
# Gentoo       120
# Chinstrap     68
# Name: species, dtype: int64

# %%
pengs_Adelie = pengs_sizeDF[pengs_sizeDF['species'] == 'Adelie']
pengs_Chinstrap = pengs_sizeDF[pengs_sizeDF['species'] == 'Chinstrap']
pengs_Gentoo = pengs_sizeDF[pengs_sizeDF['species'] == 'Gentoo']

# %%
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen              39.1             18.7              181.0
# 1    Adelie  Torgersen              39.5             17.4              186.0
# 2    Adelie  Torgersen              40.3             18.0              195.0
# 4    Adelie  Torgersen              36.7             19.3              193.0
# 5    Adelie  Torgersen              39.3             20.6              190.0
# ..      ...        ...               ...              ...                ...
# 147  Adelie      Dream              36.6             18.4              184.0
# 148  Adelie      Dream              36.0             17.8              195.0
# 149  Adelie      Dream              37.8             18.1              193.0
# 150  Adelie      Dream              36.0             17.1              187.0
# 151  Adelie      Dream              41.5             18.5              201.0
#
#      body_mass_g     sex
# ...

# %%
pengs_sizeDF.head()
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen              39.1             18.7              181.0
# 1  Adelie  Torgersen              39.5             17.4              186.0
# 2  Adelie  Torgersen              40.3             18.0              195.0
# 4  Adelie  Torgersen              36.7             19.3              193.0
# 5  Adelie  Torgersen              39.3             20.6              190.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 4       3450.0  FEMALE
# 5       3650.0    MALE

# %%
plt.figure(figsize=(8, 6))
plt.scatter(pengs_sizeDF['culmen_length_mm'], pengs_sizeDF['culmen_depth_mm'])
plt.xlabel('culmen_length_mm')
plt.ylabel('culmen_depth_mm')
correl = pengs_sizeDF['culmen_length_mm'].corr(pengs_sizeDF['culmen_depth_mm'])
plt.title(f'Penguin Culmen Length vs. Depth. Correlation: {correl} ')
plt.show()
